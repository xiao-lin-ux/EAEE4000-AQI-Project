# %% [markdown]
# # Visualizing the original dataset
#
# by Kelsey Yao

# %%
from utils import *
import seaborn as sns

aqi_df = pd.read_csv(file_dir)
aqi_df.sample(5)
# Out:
#         Country            City  AQI Value AQI Category  CO AQI Value  \
# 16903  Pakistan          Gambat        168    Unhealthy             1
# 2971      India      Jharsuguda        154    Unhealthy             2
# 22423    Poland           Nisko         65     Moderate             1
# 15669     India  Nagireddipalle         85     Moderate             0
# 4006    Germany     Blieskastel         69     Moderate             2
#
#       CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 16903            Good               48               Good              1
# 2971             Good               67           Moderate              2
# 22423            Good               46               Good              0
# 15669            Good               26               Good              0
# 4006             Good               25               Good              5
#
#       NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# ...

# %%
# plot a histogram of the numeric data
def make_hist(data, width, height):
    cols = data.select_dtypes(include=('number')).columns.to_list()
    data[cols].hist(bins=30, figsize=(width, height))
    plt.show()

make_hist(aqi_df,width=12,height=9)

# %%
# plot a correlation matrix heatmat of the numberic data
def make_heatmap(data):
    cols = data.select_dtypes(include=('number'))
    corr_matrix = cols.corr()
    sns.heatmap(data=corr_matrix,
                cmap='Oranges', 
                linecolor='0000',
                linewidths=.1,
                annot=True)
    plt.title('Linear correlations')
    plt.show()

make_heatmap(aqi_df)

# %%
# get a random sampling of 100 cities out of the dataset
import random
indices = random.sample(range(0,len(aqi_df)-1),50)
sample_df = aqi_df.iloc[indices]

# %%
# plotting
sample_city_np = sample_df['City'].to_numpy() # get the city names for the x values
sample_aqi_np = sample_df['AQI Value'].to_numpy() # get the aqi values for the y values

width=10
height=5

fig = plt.figure(figsize = (width,height))
plt.bar(sample_city_np,sample_aqi_np, width=0.5)
plt.xlabel("City")
plt.xticks(rotation=90)
plt.ylabel("AQI")
plt.title("Given AQI values for 50 random cities")
plt.show()
