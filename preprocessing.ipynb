# %% [markdown]
# For now, this notebook serves as a basic NN training test. #WIP
#
# By Xiao Lin

# %%
from utils import *

aqi_df = df_prep(file_dir)
aqi_df
# Out:
#                    City  AQI Value  CO AQI Value  Ozone AQI Value  \
# 0            Praskoveya         51             1               36
# 1      Presidente Dutra         41             1                5
# 2       Priolo Gargallo         66             1               39
# 3             Przasnysz         34             1               34
# 4              Punaauia         22             0               22
# ...                 ...        ...           ...              ...
# 23458      Gursahaiganj        184             3              154
# 23459            Sceaux         50             1               20
# 23460          Mormugao         50             1               22
# 23461       Westerville         71             1               44
# 23462            Marang         70             1               38
#
#        NO2 AQI Value  PM2.5 AQI Value
# 0                  0               51
# 1                  1               41
# 2                  2               66
# ...
